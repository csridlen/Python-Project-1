# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/311_Service_Requests_-_Pot_Holes_Reported_-_Historical.csv")

# %%
data['creation_date'] = pd.to_datetime(data['CREATION DATE'])
data['completion_date'] = pd.to_datetime(data['completion_date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'completion_date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#wanted to calculate the duration

# %%
data.columns
# Out:
# Index(['CREATION DATE', 'STATUS', 'COMPLETION DATE', 'SERVICE REQUEST NUMBER',
#        'TYPE OF SERVICE REQUEST', 'CURRENT ACTIVITY', 'MOST RECENT ACTION',
#        'NUMBER OF POTHOLES FILLED ON BLOCK', 'STREET ADDRESS', 'ZIP',
#        'X COORDINATE', 'Y COORDINATE', 'Ward', 'Police District',
#        'Community Area', 'SSA', 'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %%
data['year'] = pd.DatetimeIndex(data['CREATION DATE']).year

# %%
data1 = data.groupby(["year"])['CREATION DATE'].count()

# %%
data1.head()
# Out:
# year
# 2009        3
# 2010      608
# 2011    80162
# 2012    43237
# 2013    69630
# Name: CREATION DATE, dtype: int64

# %%
plt.plot(data1.index, data1)
