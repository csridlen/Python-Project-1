# %%
# %load_ext lab_black
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import statsmodels.formula.api as smf

# %%
potholes_1 = pd.read_csv("../data/potholes_1.csv")
potholes_2 = pd.read_csv("../data/potholes_2.csv")
census_data = pd.read_csv("../data/chicago_census_data.csv")

# %%
data = pd.concat([potholes_1, potholes_2], ignore_index=True)

# %%
# Renaming columns
data = data.rename(
    columns={
        "CREATION DATE": "Creation Date",
        "STATUS": "Status",
        "COMPLETION DATE": "Completion Date",
        "SERVICE REQUEST NUMBER": "Srn",
        "TYPE OF SERVICE REQUEST": "Type",
        "CURRENT ACTIVITY": "Current Activity",
        "MOST RECENT ACTION": "Action",
        "NUMBER OF POTHOLES FILLED ON BLOCK": "Potholes",
        "STREET ADDRESS": "Address",
        "ZIP": "zip",
        "X COORDINATE": "x coordinate",
        "Y COORDINATE": "y coordinate",
        "Ward": "ward",
        "Police District": "Police District",
        " Community Area": "Area",
        "SSA": "ssa",
        "LATITUDE": "Latitude",
        "LONGITUDE": "Longitude",
        "LOCATION": "Location",
    }
)
data.columns
# Out:
# Index(['Creation Date', 'Status', 'Completion Date', 'Srn', 'Type',
#        'Current Activity', 'Action', 'Potholes', 'Address', 'zip',
#        'x coordinate', 'y coordinate', 'ward', 'Police District',
#        'Community Area', 'ssa', 'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
census_data = census_data.rename(
    columns={
        "Community Area Number": "Community Area",
        "PER CAPITA INCOME ": "PCI",
        "HARDSHIP INDEX": "HI",
    }
)
census_data["log_value_pci"] = np.log(census_data["PCI"])
census_data.columns
# Out:
# Index(['Community Area', 'COMMUNITY AREA NAME', 'PERCENT OF HOUSING CROWDED',
#        'PERCENT HOUSEHOLDS BELOW POVERTY', 'PERCENT AGED 16+ UNEMPLOYED',
#        'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA',
#        'PERCENT AGED UNDER 18 OR OVER 64', 'PCI', 'HI', 'log_value_pci'],
#       dtype='object')

# %%
data_new = pd.merge(data, census_data, on=["Community Area"])
data_new.head()
data_new.shape
# Out:
# (558912, 28)

# %%
# setting date as an index
data_new["Creation Date"] = pd.to_datetime(data["Creation Date"])
data_new.set_index("Creation Date", inplace=True)

# %%
from datetime import datetime

a = datetime.strptime("2011-07-01", "%Y-%m-%d")
if a.month == datetime.now().month:
    print("This month")

# %%
# sorting by first name
data_new.sort_values("Srn", inplace=True)

# dropping ALL duplicate values
data_new.drop_duplicates(subset="Srn", keep=False, inplace=True)

# %%
# Replace the missing values for numerical columns with mean
data["ssa"] = data["ssa"].fillna(data["ssa"].mean())
data["Potholes"] = data["Potholes"].fillna(data["Potholes"].mean())
# Replace the missing values for numerical columns with mode
data["Current Activity"] = data["Current Activity"].fillna(
    data["Current Activity"].mode()[0]
)
data["Action"] = data["Action"].fillna(data["Action"].mode()[0])
data["x coordinate"] = data["x coordinate"].fillna(data["x coordinate"].mode()[0])
data["y coordinate"] = data["y coordinate"].fillna(data["y coordinate"].mode()[0])
# Replace the missing value of competion date by a future date using 'fillna' method
data["Completion Date"] = data["Completion Date"].fillna(12 / 18 / 2022)
data["zip"] = data["zip"].fillna(0)
data["Address"] = data["Address"].fillna(0)
data["ward"] = data["ward"].fillna(0)
data["Police District"] = data["Police District"].fillna(0)
data["Community Area"] = data["Community Area"].fillna(0)
data["Latitude"] = data["Latitude"].fillna(0)
data["Longitude"] = data["Longitude"].fillna(0)
data["Location"] = data["Location"].fillna(0)

# %%
census_data["Community Area"] = census_data["Community Area"].fillna(0)
census_data["HI"] = census_data["HI"].fillna(0)

# %%
census_data.isnull().sum()
# Out:
# Community Area                                  0
# COMMUNITY AREA NAME                             0
# PERCENT OF HOUSING CROWDED                      0
# PERCENT HOUSEHOLDS BELOW POVERTY                0
# PERCENT AGED 16+ UNEMPLOYED                     0
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA    0
# PERCENT AGED UNDER 18 OR OVER 64                0
# PCI                                             0
# HI                                              0
# log_value_pci                                   0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Creation Date       0
# Status              0
# Completion Date     0
# Srn                 0
# Type                0
# Current Activity    0
# Action              0
# Potholes            0
# Address             0
# zip                 0
# x coordinate        0
# y coordinate        0
# ward                0
# Police District     0
# Community Area      0
# ssa                 0
# Latitude            0
# Longitude           0
# Location            0
# dtype: int64

# %%
results1 = smf.ols("Potholes ~ log_value_pci + HI", data=data_new).fit()
print(results1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Potholes   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1389.
# Date:                Tue, 22 Mar 2022   Prob (F-statistic):               0.00
# Time:                        15:48:51   Log-Likelihood:            -1.7026e+06
# No. Observations:              395619   AIC:                         3.405e+06
# Df Residuals:                  395616   BIC:                         3.405e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        39.9720      1.984     20.144      0.000      36.083      43.861
# log_value_pci    -2.8766      0.182    -15.778      0.000      -3.234      -2.519
# HI               -0.0001      0.003     -0.040      0.968      -0.007       0.006
# ==============================================================================
# Omnibus:                   356587.180   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17334875.531
# Skew:                           4.251   Prob(JB):                         0.00
# Kurtosis:                      34.294   Cond. No.                     3.81e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
data.describe()
# Out:
#             Potholes            zip  x coordinate  y coordinate  \
# count  560478.000000  560478.000000  5.604780e+05  5.604780e+05
# mean       10.917616   60303.485999  1.160043e+06  1.892140e+06
# std        15.143209    4451.120310  1.736707e+04  3.548172e+04
# min         0.000000       0.000000  1.092430e+06  1.813892e+06
# 25%         2.000000   60619.000000  1.148706e+06  1.861000e+06
# 50%        10.917616   60630.000000  1.160756e+06  1.898819e+06
# 75%        10.917616   60643.000000  1.171910e+06  1.922107e+06
# max       320.000000   60827.000000  1.205133e+06  1.951593e+06
#
#                 ward  Police District  Community Area            ssa  \
# count  560478.000000    560478.000000   560478.000000  560478.000000
# mean       25.707680        13.140468       35.124403      32.442022
# std        14.222005         6.987750       23.516352       6.828806
# min         0.000000         0.000000        0.000000       1.000000
# 25%        13.000000         8.000000       15.000000      32.442022
# 50%        26.000000        14.000000       29.000000      32.442022
# 75%        38.000000        18.000000       58.000000      32.442022
# max        50.000000        31.000000       77.000000      69.000000
#
#             Latitude      Longitude
# count  560478.000000  560478.000000
# mean       41.793837     -87.550287
# std         1.662114       3.476376
# min         0.000000     -87.936132
# 25%        41.773565     -87.729681
# 50%        41.877518     -87.685376
# 75%        41.942314     -87.644831
# max        42.022960       0.000000

# %%
data_new.corr()
# Out:
#                                               Potholes       zip  \
# Potholes                                      1.000000  0.000006
# zip                                           0.000006  1.000000
# x coordinate                                  0.037678 -0.010268
# y coordinate                                 -0.099520  0.002492
# ward                                         -0.070748  0.009426
# Police District                              -0.057326  0.019625
# Community Area                                0.090452  0.001407
# ssa                                           0.033976 -0.020978
# Latitude                                     -0.049872  0.001598
# Longitude                                     0.005556 -0.002359
# PERCENT OF HOUSING CROWDED                    0.008659 -0.001181
# PERCENT HOUSEHOLDS BELOW POVERTY              0.061410 -0.000829
# PERCENT AGED 16+ UNEMPLOYED                   0.101595  0.001712
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  0.033857 -0.002749
# PERCENT AGED UNDER 18 OR OVER 64              0.104333  0.007109
# PCI                                          -0.080473 -0.005658
# HI                                            0.079662 -0.000150
# log_value_pci                                -0.083554 -0.003348
#
#                                               x coordinate  y coordinate  \
# Potholes                                          0.037678     -0.099520
# zip                                              -0.010268      0.002492
# x coordinate                                      1.000000     -0.531707
# y coordinate                                     -0.531707      1.000000
# ward                                             -0.470308      0.717848
# Police District                                  -0.465859      0.594048
# Community Area                                    0.287502     -0.809395
# ssa                                               0.329935     -0.144119
# Latitude                                         -0.310696      0.578718
# Longitude                                         0.215471     -0.111112
# PERCENT OF HOUSING CROWDED                       -0.216671      0.083402
# PERCENT HOUSEHOLDS BELOW POVERTY                  0.361744     -0.308073
# PERCENT AGED 16+ UNEMPLOYED                       0.251064     -0.554050
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA     -0.170541     -0.145511
# PERCENT AGED UNDER 18 OR OVER 64                 -0.086079     -0.491409
# PCI                                               0.119437      0.334266
# HI                                                0.058755     -0.389393
# log_value_pci                                     0.049353      0.388310
#
#                                                   ward  Police District  \
# Potholes                                     -0.070748        -0.057326
# zip                                           0.009426         0.019625
# x coordinate                                 -0.470308        -0.465859
# y coordinate                                  0.717848         0.594048
# ward                                          1.000000         0.666048
# Police District                               0.666048         1.000000
# Community Area                               -0.587604        -0.463177
# ssa                                          -0.179225        -0.136880
# Latitude                                      0.417538         0.346493
# Longitude                                    -0.100754        -0.100635
# PERCENT OF HOUSING CROWDED                   -0.031336         0.036177
# PERCENT HOUSEHOLDS BELOW POVERTY             -0.368981        -0.363221
# PERCENT AGED 16+ UNEMPLOYED                  -0.449368        -0.409937
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA -0.216895        -0.134631
# PERCENT AGED UNDER 18 OR OVER 64             -0.285876        -0.202985
# PCI                                           0.286425         0.210241
# HI                                           -0.359066        -0.293801
# log_value_pci                                 0.329905         0.258477
#
#                                               Community Area       ssa  \
# Potholes                                            0.090452  0.033976
# zip                                                 0.001407 -0.020978
# x coordinate                                        0.287502  0.329935
# y coordinate                                       -0.809395 -0.144119
# ward                                               -0.587604 -0.179225
# Police District                                    -0.463177 -0.136880
# Community Area                                      1.000000 -0.013127
# ssa                                                -0.013127  1.000000
# Latitude                                           -0.467715 -0.144790
# Longitude                                           0.058639  0.329725
# PERCENT OF HOUSING CROWDED                          0.008051 -0.067587
# PERCENT HOUSEHOLDS BELOW POVERTY                    0.224738  0.170418
# PERCENT AGED 16+ UNEMPLOYED                         0.486314  0.305178
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA        0.204934 -0.107203
# PERCENT AGED UNDER 18 OR OVER 64                    0.458775  0.224149
# PCI                                                -0.417726 -0.147187
# HI                                                  0.376242  0.071013
# log_value_pci                                      -0.427209 -0.082955
#
#                                               Latitude  Longitude  \
# Potholes                                     -0.049872   0.005556
# zip                                           0.001598  -0.002359
# x coordinate                                 -0.310696   0.215471
# y coordinate                                  0.578718  -0.111112
# ward                                          0.417538  -0.100754
# Police District                               0.346493  -0.100635
# Community Area                               -0.467715   0.058639
# ssa                                          -0.144790   0.329725
# Latitude                                      1.000000  -0.861236
# Longitude                                    -0.861236   1.000000
# PERCENT OF HOUSING CROWDED                    0.050050  -0.048044
# PERCENT HOUSEHOLDS BELOW POVERTY             -0.178512   0.076695
# PERCENT AGED 16+ UNEMPLOYED                  -0.318750   0.049965
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA -0.081388  -0.040032
# PERCENT AGED UNDER 18 OR OVER 64             -0.279580  -0.025369
# PCI                                           0.189592   0.030929
# HI                                           -0.222184   0.007829
# log_value_pci                                 0.220727   0.016236
#
#                                               PERCENT OF HOUSING CROWDED  \
# Potholes                                                        0.008659
# zip                                                            -0.001181
# x coordinate                                                   -0.216671
# y coordinate                                                    0.083402
# ward                                                           -0.031336
# Police District                                                 0.036177
# Community Area                                                  0.008051
# ssa                                                            -0.067587
# Latitude                                                        0.050050
# Longitude                                                      -0.048044
# PERCENT OF HOUSING CROWDED                                      1.000000
# PERCENT HOUSEHOLDS BELOW POVERTY                                0.437438
# PERCENT AGED 16+ UNEMPLOYED                                     0.248276
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                    0.898798
# PERCENT AGED UNDER 18 OR OVER 64                                0.266611
# PCI                                                            -0.565718
# HI                                                              0.716641
# log_value_pci                                                  -0.662534
#
#                                               PERCENT HOUSEHOLDS BELOW POVERTY  \
# Potholes                                                              0.061410
# zip                                                                  -0.000829
# x coordinate                                                          0.361744
# y coordinate                                                         -0.308073
# ward                                                                 -0.368981
# Police District                                                      -0.363221
# Community Area                                                        0.224738
# ssa                                                                   0.170418
# Latitude                                                             -0.178512
# Longitude                                                             0.076695
# PERCENT OF HOUSING CROWDED                                            0.437438
# PERCENT HOUSEHOLDS BELOW POVERTY                                      1.000000
# PERCENT AGED 16+ UNEMPLOYED                                           0.759873
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                          0.482411
# PERCENT AGED UNDER 18 OR OVER 64                                      0.340864
# PCI                                                                  -0.537141
# HI                                                                    0.786462
# log_value_pci                                                        -0.678392
#
#                                               PERCENT AGED 16+ UNEMPLOYED  \
# Potholes                                                         0.101595
# zip                                                              0.001712
# x coordinate                                                     0.251064
# y coordinate                                                    -0.554050
# ward                                                            -0.449368
# Police District                                                 -0.409937
# Community Area                                                   0.486314
# ssa                                                              0.305178
# Latitude                                                        -0.318750
# Longitude                                                        0.049965
# PERCENT OF HOUSING CROWDED                                       0.248276
# PERCENT HOUSEHOLDS BELOW POVERTY                                 0.759873
# PERCENT AGED 16+ UNEMPLOYED                                      1.000000
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                     0.409334
# PERCENT AGED UNDER 18 OR OVER 64                                 0.659396
# PCI                                                             -0.660096
# HI                                                               0.796141
# log_value_pci                                                   -0.751541
#
#                                               PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# Potholes                                                                          0.033857
# zip                                                                              -0.002749
# x coordinate                                                                     -0.170541
# y coordinate                                                                     -0.145511
# ward                                                                             -0.216895
# Police District                                                                  -0.134631
# Community Area                                                                    0.204934
# ssa                                                                              -0.107203
# Latitude                                                                         -0.081388
# Longitude                                                                        -0.040032
# PERCENT OF HOUSING CROWDED                                                        0.898798
# PERCENT HOUSEHOLDS BELOW POVERTY                                                  0.482411
# PERCENT AGED 16+ UNEMPLOYED                                                       0.409334
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                                      1.000000
# PERCENT AGED UNDER 18 OR OVER 64                                                  0.443776
# PCI                                                                              -0.725263
# HI                                                                                0.839152
# log_value_pci                                                                    -0.816029
#
#                                               PERCENT AGED UNDER 18 OR OVER 64  \
# Potholes                                                              0.104333
# zip                                                                   0.007109
# x coordinate                                                         -0.086079
# y coordinate                                                         -0.491409
# ward                                                                 -0.285876
# Police District                                                      -0.202985
# Community Area                                                        0.458775
# ssa                                                                   0.224149
# Latitude                                                             -0.279580
# Longitude                                                            -0.025369
# PERCENT OF HOUSING CROWDED                                            0.266611
# PERCENT HOUSEHOLDS BELOW POVERTY                                      0.340864
# PERCENT AGED 16+ UNEMPLOYED                                           0.659396
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                          0.443776
# PERCENT AGED UNDER 18 OR OVER 64                                      1.000000
# PCI                                                                  -0.756016
# HI                                                                    0.682522
# log_value_pci                                                        -0.755374
#
#                                                    PCI        HI  \
# Potholes                                     -0.080473  0.079662
# zip                                          -0.005658 -0.000150
# x coordinate                                  0.119437  0.058755
# y coordinate                                  0.334266 -0.389393
# ward                                          0.286425 -0.359066
# Police District                               0.210241 -0.293801
# Community Area                               -0.417726  0.376242
# ssa                                          -0.147187  0.071013
# Latitude                                      0.189592 -0.222184
# Longitude                                     0.030929  0.007829
# PERCENT OF HOUSING CROWDED                   -0.565718  0.716641
# PERCENT HOUSEHOLDS BELOW POVERTY             -0.537141  0.786462
# PERCENT AGED 16+ UNEMPLOYED                  -0.660096  0.796141
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA -0.725263  0.839152
# PERCENT AGED UNDER 18 OR OVER 64             -0.756016  0.682522
# PCI                                           1.000000 -0.838876
# HI                                           -0.838876  1.000000
# log_value_pci                                 0.954451 -0.954373
#
#                                               log_value_pci
# Potholes                                          -0.083554
# zip                                               -0.003348
# x coordinate                                       0.049353
# y coordinate                                       0.388310
# ward                                               0.329905
# Police District                                    0.258477
# Community Area                                    -0.427209
# ssa                                               -0.082955
# Latitude                                           0.220727
# Longitude                                          0.016236
# PERCENT OF HOUSING CROWDED                        -0.662534
# PERCENT HOUSEHOLDS BELOW POVERTY                  -0.678392
# PERCENT AGED 16+ UNEMPLOYED                       -0.751541
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA      -0.816029
# PERCENT AGED UNDER 18 OR OVER 64                  -0.755374
# PCI                                                0.954451
# HI                                                -0.954373
# log_value_pci                                      1.000000
